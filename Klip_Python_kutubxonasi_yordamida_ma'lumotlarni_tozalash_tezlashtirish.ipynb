# %% [markdown]
# <a href="https://colab.research.google.com/github/mamatqobulovsardor/Klip_Python_kutubxonasi_yordamida_ma-lumotlarni_tozalash_tezlashtirish/blob/main/Klip_Python_kutubxonasi_yordamida_ma'lumotlarni_tozalash_tezlashtirish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# How to Speed Up Data Cleaning with the klib Python library

# %%
! pip install klib
# Out:
# Collecting klib
#   Downloading klib-1.3.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: jinja2>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from klib) (3.1.4)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from klib) (3.8.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from klib) (1.26.4)
# Requirement already satisfied: pandas<3.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from klib) (2.2.2)
# Requirement already satisfied: plotly>=5.11.0 in /usr/local/lib/python3.10/dist-packages (from klib) (5.24.1)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from klib) (1.13.1)
# Collecting screeninfo>=0.8.1 (from klib)
#   Downloading screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from klib) (0.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.1.0->klib) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->klib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->klib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->klib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->klib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->klib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->klib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->klib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->klib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.4->klib) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.4->klib) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.11.0->klib) (9.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->klib) (1.16.0)
# Downloading klib-1.3.2-py3-none-any.whl (23 kB)
# Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Installing collected packages: screeninfo, klib
# Successfully installed klib-1.3.2 screeninfo-0.8.1

# %%
import klib
import pandas as pd

# %%
df = pd.read_csv('https://github.com/akanz1/klib/raw/main/examples/NFL_DATASET.csv')
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %% [markdown]
# Ma'lumotlarni tozalash

# %%
df_cleaned = klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (183460, 63) - Remaining NAs: 2104874
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 4
#      of which 1 single valued.     Columns: ['play_attempted']
# Dropped missing values: 520667
# Reduced memory by at least: 65.86 MB (-70.23%)

# %% [markdown]
# Barcha korrelyatsiya ma'lumotlarini ko'rsatish.

# %%
klib.corr_plot(df_cleaned, annot=False)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %% [markdown]
# Display only positive correlation.

# %%
klib.corr_plot(df_cleaned, split='pos', annot=False)
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %% [markdown]
# Faqat salbiy korrelyatsiyani ko'rsating.

# %%
klib.corr_plot(df_cleaned, split='neg', annot=False)
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %% [markdown]
# Display correlation with a target variable of interest

# %%
klib.corr_plot(df_cleaned, target='touchdown')
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.corr_mat(df_cleaned)
# Out:
# /usr/local/lib/python3.10/dist-packages/klib/describe.py:275: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_e763e_row0_col0, #T_e763e_row0_col7, #T_e763e_row0_col8, #T_e763e_row0_col10, #T_e763e_row0_col11, #T_e763e_row0_col12, #T_e763e_row0_col13, #T_e763e_row0_col20, #T_e763e_row0_col22, #T_e763e_row0_col31, #T_e763e_row0_col33, #T_e763e_row0_col34, #T_e763e_row0_col36, #T_e763e_row0_col38, #T_e763e_row0_col40, #T_e763e_row0_col42, #T_e763e_row0_col43, #T_e763e_row0_col44, #T_e763e_row1_col1, #T_e763e_row1_col2, #T_e763e_row1_col5, #T_e763e_row1_col7, #T_e763e_row1_col8, #T_e763e_row1_col11, #T_e763e_row1_col12, #T_e763e_row1_col13, #T_e763e_row1_col14, #T_e763e_row1_col15, #T_e763e_row1_col16, #T_e763e_row1_col18, #T_e763e_row1_col19, #T_e763e_row1_col22, #T_e763e_row1_col23, #T_e763e_row1_col24, #T_e763e_row1_col32, #T_e763e_row1_col35, #T_e763e_row1_col37, #T_e763e_row1_col39, #T_e763e_row1_col43, #T_e763e_row2_col1, #T_e763e_row2_col2, #T_e763e_row2_col4, #T_e763e_row2_col5, #T_e763e_row2_col9, #T_e763e_row2_col11, #T_e763e_row2_col13, #T_e763e_row2_col14, #T_e763e_row2_col18, #T_e763e_row2_col19, #T_e763e_row2_col22, #T_e763e_row2_col23, #T_e763e_row2_col24, #T_e763e_row2_col25, #T_e763e_row2_col26, #T_e763e_row2_col27, #T_e763e_row2_col28, #T_e763e_row2_col29, #T_e763e_row2_col31, #T_e763e_row2_col32, #T_e763e_row2_col34, #T_e763e_row2_col35, #T_e763e_row2_col37, #T_e763e_row2_col39, #T_e763e_row2_col42, #T_e763e_row2_col43, #T_e763e_row3_col3, #T_e763e_row3_col4, #T_e763e_row3_col5, #T_e763e_row3_col6, #T_e763e_row3_col9, #T_e763e_row3_col10, #T_e763e_row3_col15, #T_e763e_row3_col16, #T_e763e_row3_col17, #T_e763e_row3_col18, #T_e763e_row3_col20, #T_e763e_row3_col21, #T_e763e_row3_col22, #T_e763e_row3_col23, #T_e763e_row3_col25, #T_e763e_row3_col26, #T_e763e_row3_col27, #T_e763e_row3_col28, #T_e763e_row3_col29, #T_e763e_row3_col30, #T_e763e_row3_col33, #T_e763e_row3_col36, #T_e763e_row3_col38, #T_e763e_row3_col40, #T_e763e_row3_col41, #T_e763e_row3_col42, #T_e763e_row3_col44, #T_e763e_row4_col2, #T_e763e_row4_col3, #T_e763e_row4_col4, #T_e763e_row4_col5, #T_e763e_row4_col6, #T_e763e_row4_col7, #T_e763e_row4_col8, #T_e763e_row4_col9, #T_e763e_row4_col12, #T_e763e_row4_col15, #T_e763e_row4_col16, #T_e763e_row4_col17, #T_e763e_row4_col18, #T_e763e_row4_col19, #T_e763e_row4_col20, #T_e763e_row4_col21, #T_e763e_row4_col22, #T_e763e_row4_col23, #T_e763e_row4_col24, #T_e763e_row4_col27, #T_e763e_row4_col28, #T_e763e_row4_col29, #T_e763e_row4_col30, #T_e763e_row4_col33, #T_e763e_row4_col37, #T_e763e_row4_col39, #T_e763e_row4_col41, #T_e763e_row4_col44, #T_e763e_row5_col1, #T_e763e_row5_col2, #T_e763e_row5_col3, #T_e763e_row5_col4, #T_e763e_row5_col5, #T_e763e_row5_col6, #T_e763e_row5_col9, #T_e763e_row5_col10, #T_e763e_row5_col14, #T_e763e_row5_col15, #T_e763e_row5_col16, #T_e763e_row5_col17, #T_e763e_row5_col18, #T_e763e_row5_col19, #T_e763e_row5_col21, #T_e763e_row5_col22, #T_e763e_row5_col23, #T_e763e_row5_col25, #T_e763e_row5_col27, #T_e763e_row5_col28, #T_e763e_row5_col29, #T_e763e_row5_col30, #T_e763e_row5_col33, #T_e763e_row5_col36, #T_e763e_row5_col38, #T_e763e_row5_col40, #T_e763e_row5_col44, #T_e763e_row6_col3, #T_e763e_row6_col4, #T_e763e_row6_col5, #T_e763e_row6_col6, #T_e763e_row6_col10, #T_e763e_row6_col13, #T_e763e_row6_col15, #T_e763e_row6_col16, #T_e763e_row6_col17, #T_e763e_row6_col18, #T_e763e_row6_col19, #T_e763e_row6_col20, #T_e763e_row6_col21, #T_e763e_row6_col22, #T_e763e_row6_col23, #T_e763e_row6_col24, #T_e763e_row6_col25, #T_e763e_row6_col26, #T_e763e_row6_col27, #T_e763e_row6_col28, #T_e763e_row6_col29, #T_e763e_row6_col30, #T_e763e_row6_col33, #T_e763e_row6_col36, #T_e763e_row6_col44, #T_e763e_row7_col0, #T_e763e_row7_col1, #T_e763e_row7_col4, #T_e763e_row7_col7, #T_e763e_row7_col8, #T_e763e_row7_col9, #T_e763e_row7_col10, #T_e763e_row7_col11, #T_e763e_row7_col12, #T_e763e_row7_col15, #T_e763e_row7_col16, #T_e763e_row7_col17, #T_e763e_row7_col20, #T_e763e_row7_col21, #T_e763e_row7_col24, #T_e763e_row7_col28, #T_e763e_row7_col30, #T_e763e_row7_col31, #T_e763e_row7_col32, #T_e763e_row7_col33, #T_e763e_ro ...

# %%
klib.dist_plot(df_cleaned['win_prob'])
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <Axes: xlabel='win_prob', ylabel='Density'>

# %% [markdown]
# Categorical Plot

# %%
klib.cat_plot(df, figsize=(50,15))
# Out:
# GridSpec(6, 21)

# %% [markdown]
# Save Plot as a PDF file

# %%
plot = klib.corr_plot(df_cleaned, annot=False, figsize=(12,10))

# %%
plot.figure.savefig('figure.pdf')
